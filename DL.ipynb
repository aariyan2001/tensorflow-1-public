# %% [markdown]
# <a href="https://colab.research.google.com/github/aariyan2001/tensorflow-1-public/blob/main/DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype=float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype=float)

# %%
import tensorflow as tf
from tensorflow import keras
model = keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer="sgd" , loss = "mean_squared_error")
model.fit(xs,ys, epochs=500)  #epoches 500 means it goes through the training loop 500 times
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 412ms/step - loss: 28.0945
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 22.4078
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 17.9276
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 14.3966
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 11.6126
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.4164
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.6828
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 6.3133
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.2302
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3728
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.6928
# Epoch 12/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1527
# ...
